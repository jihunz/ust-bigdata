# %% [markdown]
# #파이썬 기초 실습

# %% [markdown]
# #기본자료형

# %%
a = 123    #정수형
print(type(a))

# %%
a = 12.34  #실수형
print(type(a))

# %%
a = 1 + 2j #복소수형
print(type(a))

# %%
b = True  #논리형 - 참과 거짓
print(type(b))

# %%
b

# %% [markdown]
# #사칙연산

# %%
a = 3

# %%
b = 4

# %%
a + b

# %%
a - b

# %%
a * b

# %%
a / b

# %%
a ** b # a의 b승

# %%
2 ** 3 #2의 3승

# %%
a % b  #나머지를 구하는 연산자

# %%
7 % 3

# %%
a // b #몫을 구하는 연산자

# %%
7 // 3

# %% [markdown]
# #논리형 관계 연산자

# %%
1 > 3

# %%
1 < 3

# %%
1 == 3

# %%
1 != 3

# %% [markdown]
# #자료형-문자열

# %%
s1 = 'Hello Python'

# %%
s1

# %%
s2 = "Hello Python"

# %%
s2

# %%
s3 = '''Hello Python'''

# %%
s3

# %%
s4 = """Hello Python"""

# %%
s4

# %%
head = "Python"

# %%
tail = " is fun"

# %%
head + tail #결합 연산자

# %%
head * 2 #반복 연산

# %%
print("=" * 5)

# %%
a = "Now is better than never"

# %%
a[0] #indexing 첫번째 글자

# %%
a[4]

# %%
a[-1]

# %%
a[-2]

# %%
s1 = 'Hello Python'

# %%
s1

# %%
s2 = "Hello Python"

# %%
s2

# %%
s3 = '''Hello Python'''

# %%
s3

# %%
s4 = """Hello Python"""

# %%
s4

# %%
head = "Python"

# %%
tail = " is fun"

# %%
head + tail #결합 연산자

# %%
head * 2 #반복 연산

# %%
print("=" * 5)

# %% [markdown]
# #문자열 인덱싱, 슬라이싱

# %%
a = "Now is better than never"

# %%
a[0] #indexing 첫번째 글자

# %%
a[4]

# %%
a[-1] #마지막 글자

# %%
a[-2]

# %%
b = a[0] + a[1] + a[2] #결합 연산

# %%
b

# %%
a[0:3] #Slicing (앞 포함, 뒤 불포함)

# %%
a[4:6]

# %%
a[19:] #Slicing (앞 포함, 뒤 불포함)

# %%
a[:3]

# %%
a[:] #모든 문자열

# %%
a[7:-11]

# %% [markdown]
# #문자열 사용 가능 함수

# %%
a = "Python"

# %%
a.count('p') #문자 개수 세기

# %%
a.find('y') #y의 첫번째 인덱스

# %%
a.find('p') #없으면 -1

# %%
a.index('y')

# %%
a.index('p') #없으면 에러

# %%
b = ","

# %%
c = b.join('Abcd') #b를 기준으로 결합

# %%
c

# %%
a.upper() #대문자로 변환

# %%
a.lower() #소문자로 변환

# %%
d = " py " #왼쪽 공백 제거

# %%
d.lstrip()

# %%
d.rstrip() #오른쪽 공백 제거

# %%
d.strip() #양쪽 공백 제거

# %%
a = 'Pithon’ #string은 수정불가 immutable

# %%
a[1] = 'y'

# %%
a = "Python is difficult."

# %%
a.replace("difficult", "funny") # 교환

# %%
a.split() # 분리 – 옵션 없을때 공백단위

# %%
b = "a, b, c, d"

# %%
b

# %%
b.split(',') # , 기준으로 분리

# %% [markdown]
# #자료형-리스트(List): 순서를 갖는 파이썬 임의 객체의 집합적 자료형

# %%
a = [1, 2, 3]

# %%
b = ['Life', 'is', 'too', 'short']

# %%
c = [1, 2, 'Life', 'is']

# %%
d = [1, 2, [3, 4], ['Life', 'is']] # 다양한 자료형 객체들을 원소로 가질수 있음

# %%
d[0] # 인덱싱

# %%
d[2]

# %%
d[3]

# %%
d[3][-1] #중첩 인덱싱

# %%
d[0:3] #슬라이싱

# %%
a + b #리스트 결합

# %%
b[0] + " hi~ ^^;" # 문자열과 문자열의 결합  + 연산자는 operand의 type에 따라 동작이 달라짐

# %%
a[0] + " hi~ ^^;" # operand의 type이 다를때 + 연산을 지원하지 않음

# %%
a * 3 #반복

# %%
a[2] = 99 #할당(교체) 가능 c.f) 문자열

# %%
a

# %%
a[1:2] = ['a', 'b', 'c'] #1의 위치에 교체

# %%
a

# %%
a[-1] = ['d', 'e', 'f'] #마지막 원소를 교체

# %%
a

# %%
del a[-1] #마지막 원소 삭제

# %%
a

# %%
b.sort() #정렬

# %%
b

# %%
a = [3, 4, 1, 9]

# %%
a.reverse() #원소들의 순서 뒤집기

# %%
a

# %%
a.index(9) #해당원소를 찾아 index 리턴

# %%
a.insert(0, 99) #0의 위치에 99를 삽입

# %%
a

# %%
a.remove(99) #해당원소를 찾아 삭제

# %%
a

# %%
b = [1, 2, 3] #마지막 원소 삭제(append의 반대)

# %%
b.pop()

# %%
b

# %%
b.pop(0) #인덱스 지정 삭제

# %%
b

# %%
a = [2, 1, 0, 2, 3, 2, 4, 2]

# %%
a.count(2) #해당원소의 개수 세기

# %% [markdown]
# #자료형-튜플: 순서를 갖는 파이썬 임의 객체의 집합적 자료형

# %%
t1 = (1, )

# %%
t2 = (1, 2, 3)

# %%
t3 = 1, 2, 3

# %%
t4 = (1, 2, (3, 4), ('Life', 'is'))

# %%
t4[0]

# %%
t4[3][-1]

# %%
t4[0:3]

# %%
t1 + t2

# %%
t1 + "hi~ ^^;" # operand의 type이 다를때 + 연산을 지원하지 않음

# %%
t2 * 3

# %%
t2[2] = 99 #할당(교체) 불가능

# %% [markdown]
# #자료형-사전: Key를 이용해 Value 를 참조하는 mapping형 자료구조

# %%
dic = {'name':'Hong', 'phone':'01012345678', 'birth':'0814'} #사전 만들기

# %%
dic[1] = 'a' #새로운 원소 추가

# %%
dic

# %%
dic['pet'] = 'dog'

# %%
dic

# %%
del dic[1]

# %%
dic

# %%
dic['pet'] #key로 해당 value 반환

# %%
dic['name']

# %%
dic.keys() #key 만 반환

# %%
type(dic.keys())

# %%
list(dic.keys()) # key만 반환해서 list로 변환

# %%
dic.values() # value만 반환

# %%
list(dic.values())

# %%
dic.items()

# %%
dic.clear()

# %%
dic

# %% [markdown]
# #자료형-집합(set): 집합에 관련된 것을 쉽게 처리하기 위해 만든 자료형

# %%
s1 = {1, 2, 'a', 5}

# %%
s1

# %%
s2 = set([1, 2, 3, 4, 5, 6])

# %%
s2

# %%
s3 = set([4, 5, 6, 7, 8, 9])

# %%
s3

# %%
s2 & s3

# %%
s2.intersection(s3)

# %%
s2 | s3

# %%
s2.union(s3)

# %%
s2 - s3

# %%
s2.difference(s3)

# %%
s3.difference(s2)

# %%
s2.add(7)

# %%
s2

# %%
s2.update([6, 7, 8, 9, 10])

# %%
s2

# %%
s2.remove(7)

# %%
s2

# %% [markdown]
# # 조건문과 반복문

# %%
x = 3

# %%
y = 2

# %%
x == y

# %%
x != y

# %%
x >= y

# %%
money = 1300

# %% [markdown]
# * if 조건문

# %%
if money >= 1200 and money < 3500:
 	print("버스를 탈 수 있습니다.")

# %%
1 in [1, 2, 3] #멤버쉽 테스트, 속해 있으면 true 그렇지 않으면 false

# %%
x in [1, 2, 3]

# %%
x not in [1, 2, 3] ##멤버쉽 테스트, 속해 있지 않으면 true 그렇지 않으면 false

# %%
'a' in ('a', 'b', 'c', 'd')

# %%
'i' not in 'Python'

# %%
if money < 10:
 	pass
else:
	print("저금하자!")

# %% [markdown]
# * for 반복문

# %%
test_list = ['one', 'two', 'three']

# %%
for i in test_list:
	 x = i + '!'
	 print(x)

# %%
number = 0

# %%
for score in [90, 25, 67, 45, 93]:
	 number += 1
	 if score >= 60:
	       print("%d번 학생은 합격입니다." %number)
	 else:
	       print("%d번 학생은 불합격입니다." %number)

# %%
i = 0

# %%
while i < 5:
	     i += 1
	     print('*' * i)

# %% [markdown]
# * 함수

# %%
def sum1(a, b): #사용자 함수 정의
	 x = a + b
	 return x

# %%
def sum2(*args):
	  x = 0
	  for i in args:
	        x += i
	  return x

# %%
a = 5

# %%
b = 3

# %%
sum1(a, b)

# %%
sum1(3, 5)

# %%
sum2(1, 2, 3, 4, 5)

# %%
sum2(2, 3.5, 10)

# %% [markdown]
# #파이썬 내장함수

# %%
abs(-3.5) #절대값을 출력

# %%
all([1, 2, 3, 4])

# %%
all([4, -2, 0.0, 4])

# %%
any([1, 2, 3, 4])

# %%
any([4, -2, 0.0, 4])

# %%
chr(97)

# %%
chr(48)

# %%
ord('a')

# %%
ord('0')

# %%
dir([1, 2, 3])

# %%
dir({'1':'a'})

# %%
dir(1)

# %%
divmod(7, 3)

# %%
divmod(1.3, 0.2)

# %%
oct(8)

# %%
oct(234)

# %%
hex(16)

# %%
hex(234)

# %%
a = 3

# %%
id(a)

# %% [markdown]
# * 형변환

# %%
int('3')

# %%
str(3)

# %%
list("Python")

# %%
list((1, 2, 3))

# %%
tuple("Python")

# %%
tuple([1, 2, 3])

# %%
type("abc")

# %%
type(a)

# %% [markdown]
# * 람다함수: 한줄짜리 함수, 사용자 함수 정의

# %%
sum = lambda a,b: a+b

# %%
sum

# %%
sum(3, 5)

# %%
max([1, 4, 2, 8, 6])

# %%
max("Python")

# %%
min([1, 4, 2, 8, 6])

# %%
min("Python")

# %%
pow(2, 4)

# %%
c = input() #입력을 받는 함수

# %%
c

# %%
c = input("정수를 입력하세요: ")

# %%
c

# %%
range(100) # 0부터 5까지 생성

# %%
list(range(5))

# %%
list(range (5, 10, 2))

# %%
list(range (5, 10, 2))

# %%
len('Python') #길이를 리턴해주는 함수

# %%
sorted([3, 0, 2, 1]) #데이터를 정렬해주는 함수

# %%
sorted('Python')

# %% [markdown]
# ---
# # 모듈과 패키지

# %%
Request('http://www.hanb.co.kr')

# %%
import urllib.request

# %%
urllib.request.Request('http://www.hanb.co.kr')

# %%
import pandas

# %%
pandas.DataFrame()

# %%
from datetime import datetime

# %%
datetime.now()

# %% [markdown]
# ---
# # 파일 처리

# %%
# When using Google Colab
from google.colab import drive
drive.mount('/content/drive/')
data_path='/content/drive/My Drive/Colab Notebooks/실습/data/'

# %%
# In your local PC
data_path='/Users/wonsukim/Desktop/'

# %%
#f = open("data_path:/새파일.txt", 'w') #"새파일.txt"  경로 추가 가능, w: 쓰기 모드 For Windows
f = open(data_path+"새파일.txt", 'w')  # For Mac or Linux

# %%
f

# %%
for i in range(1, 6):
	data = "%d번째 줄입니다. \n"% i
	f.write(data)

# %%
f.close()

# %%
f= open(data_path+"새파일.txt", 'a') #a: append 모드

# %%
for i in range (6, 11):
	data = "%d번째 줄 추가입니다. \n"% i
	f.write(data)

# %%
f.close()

# %%
f= open(data_path+"새파일.txt", 'r')

# %%
line = f.readline()

# %%
print(line)

# %%
while True:
	   line = f.readline()
	   if not line: break
	   print(line)

# %%
f= open(data_path+"새파일.txt", 'r') # r : 읽기 모드

# %%
lines = f.readlines()

# %%
print(lines)

# %%
for line in lines:
	print(line)

# %%
f= open(data_path+"새파일.txt", 'r')

# %%
data = f.read()

# %%
data

# %%
f.close()

# %%
with open(data_path+"새파일.txt", 'w') as f:  # with 블록이 끝날 때, f.close() 자동 호출
	 f.write("Now is better than never.")

# %%
data = f.read()
data

# %%
f = open(data_path+"새파일.txt",'r')
data = f.read()
data
# Out:
# 'Now is better than never.'

# %% [markdown]
# ---
#
#
# # 클래스

# %%
class Dog:

    def __init__(self, name):
        self.name = name
        self.tricks = []    # creates a new empty list for each dog

    def add_trick(self, trick):
        self.tricks.append(trick)

# %%
d = Dog('Fido')
e = Dog('Buddy')

# %%
d.name

# %%
e.name

# %%
d.add_trick('roll over')
e.add_trick('play dead')
d.tricks

# %%
e.tricks

# %%
class Dog:

    kind = 'canine'         # class variable shared by all instances

    def __init__(self, name):
        self.name = name    # instance variable unique to each instance

# %%
d = Dog('Fido')
e = Dog('Buddy')

# %%
d.kind

# %%
e.kind

# %%
d.name

# %%
e.name
