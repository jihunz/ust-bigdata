# %% [markdown]
# # * **(중요) '파일-드라이브에 사본 저장'을 수행함으로 본인소유의 구글  노트북으로 만들고(본인의 구글 드라이브로 복사) 실습을 시작하세요.**

# %% [markdown]
# * 다음 파이썬 문장의 결과를 예측하여 보시오

# %%
3 + 2

# %%
3 - 2

# %%
3 / 2

# %%
3 ** 2

# %%
3 % 2

# %% [markdown]
# * 실행결과를 참고하여 파이썬 코드를 완성하시오.

# %%
 str='20220426Thuesday'

# %%
year = # 결과가 2022 이 되도록 이 부분을 완성하시오. slicing 연습

# %%
year #결과 2022

# %% [markdown]
# * 다음 리스트가 있을때 이 리스트에 원소 5 를 추가하여 보시오 (append 함수 활용), 또 이 리스트의 원소의 값들을 정렬하여 보시오 (sort)활용

# %%
a = [2,3,1,4]
#다음을 완성하시오  append를 이용하여 5를 추가

# %%
#다음을 완성하시오 정렬하는 코드를 완성하시오 sort 활용

# %% [markdown]
# * 다음 코드의 실행결과를 예측해보시오.

# %%
a = ['파','이','썬']
a.reverse()
a

# %% [markdown]
# * 다음 데이터를 갖는 dictionary를 만드시오.

# %% [markdown]
# ![파이썬dic.png](data:image/png;base64,...)

# %%
#여기를 완성하시오

# %% [markdown]
# * 만든 사전(dictionary)에 height은 180, weight은 60을 추가하여 보시오

# %%
# 여기를 완성하시오.

# %% [markdown]
# * 점수를 각각 입력받아 평균을 구하는 프로그램을 작성하시오.

# %% [markdown]
# ![평균.png](data:image/png;base64,...)

# %% [markdown]
# * (Optional) 반복문과 조건문을 활용하여 학생들 점수의 grade가 아래처럼 나타날수 있도록 'pass' 부분을 수정하는 프로그램을 작성하시오.
#   - 90>= 점수: A
#   - 90> 점수 >= 80 : B
#   - 80> 점수 >= 70 : C
#   - 70> 점수 >= 60 : D
#   - 60> 점수 : F

# %%
# 다음의 예제 프로그램을 수정하세요.
sum = 0
number = 0
for score in [90, 25, 67, 45, 93]:
	#number += 1
	 number = number + 1

	 sum = sum + score
	 # 이 아래부분 수정
	 if score >= 90:
	       print("%d번 학생은 A입니다." %number)
	 elif pass:
	       print("%d번 학생은 B입니다." %number)
	 elif pass:
	       print("%d번 학생은 C입니다." %number)
	 elif score >=60 and score <70:
	       print("%d번 학생은 D입니다." %number)
	 else:
	       print("%d번 학생은 F입니다." %number)
print(sum)

# %% [markdown]
# ## **(중요) 해결한 문제들의 ipynb를 wonsukim7@gmail.com으로 공유 (파일명에 소속, 이름, 학번 추가)**

# %% [markdown]
# #
